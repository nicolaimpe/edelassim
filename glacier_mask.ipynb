# %%
from ndsi_fsc_calibration.utils import gdf_to_binary_mask
import geopandas as gpd
from observations import EdelweissGrandesRoussesGrid

glacier_mask_shapefile = (
    "/home/imperatoren/work/edelweiss_assimilation/data/auxiliary/vectorial/DATA_GLIMS_2022/glacier_2022.shp"
)
glacier_gdf = gpd.read_file(glacier_mask_shapefile)
glacier_mask = gdf_to_binary_mask(gdf=glacier_gdf, grid=EdelweissGrandesRoussesGrid())
# glacier_mask.to_netcdf(
#     "/home/imperatoren/work/edelweiss_assimilation/data/auxiliary/glacier_mask/glacier_mask_glims_2022_grandesrousses.nc"
# )
